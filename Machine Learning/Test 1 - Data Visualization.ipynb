# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('COVID 19 Cases by ZIP Code.csv')

# %%
df.head()
# Out:
#   ZIP Code  Week Number  Week Start    Week End  Cases - Weekly  \
# 0    60601           31  07/26/2020  08/01/2020             9.0
# 1    60601           30  07/19/2020  07/25/2020             8.0
# 2    60603           39  09/20/2020  09/26/2020             0.0
# 3    60611           16  04/12/2020  04/18/2020             8.0
# 4    60610           17  04/19/2020  04/25/2020            22.0
#
#    Cases - Cumulative  Case Rate - Weekly  Case Rate - Cumulative  \
# 0               116.0                61.0                   790.5
# 1               107.0                54.0                   729.1
# 2                13.0                 0.0                  1107.3
# 3                72.0                25.0                   222.0
# 4               134.0                56.0                   343.4
#
#    Tests - Weekly  Tests - Cumulative  ...  Test Rate - Cumulative  \
# 0           189.0                1901  ...                 12954.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1860 entries, 0 to 1859
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ZIP Code                              1860 non-null   object
#  1   Week Number                           1860 non-null   int64
#  2   Week Start                            1860 non-null   object
#  3   Week End                              1860 non-null   object
#  4   Cases - Weekly                        1692 non-null   float64
#  5   Cases - Cumulative                    1692 non-null   float64
#  6   Case Rate - Weekly                    1692 non-null   float64
#  7   Case Rate - Cumulative                1692 non-null   float64
#  8   Tests - Weekly                        1844 non-null   float64
#  9   Tests - Cumulative                    1860 non-null   int64
#  10  Test Rate - Weekly                    1844 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Week Number  Cases - Weekly  Cases - Cumulative  Case Rate - Weekly  \
# count  1860.000000     1692.000000         1692.000000         1692.000000
# mean     25.000000       48.452719          828.372340           90.378842
# std       8.946677       65.303238          927.343112           84.885397
# min      10.000000        0.000000            5.000000            0.000000
# 25%      17.000000       15.000000          165.250000           44.000000
# 50%      25.000000       28.000000          552.000000           67.000000
# 75%      33.000000       59.000000         1132.250000          108.000000
# max      40.000000      682.000000         5553.000000          793.000000
#
#        Case Rate - Cumulative  Tests - Weekly  Tests - Cumulative  \
# count             1692.000000     1844.000000         1860.000000
# mean              1541.737707      385.606291         4993.743548
# std               1108.621790      329.034250         5593.262012
# ...

# %%
df.columns
# Out:
# Index(['ZIP Code', 'Week Number', 'Week Start', 'Week End', 'Cases - Weekly',
#        'Cases - Cumulative', 'Case Rate - Weekly', 'Case Rate - Cumulative',
#        'Tests - Weekly', 'Tests - Cumulative', 'Test Rate - Weekly',
#        'Test Rate - Cumulative', 'Percent Tested Positive - Weekly',
#        'Percent Tested Positive - Cumulative', 'Deaths - Weekly',
#        'Deaths - Cumulative', 'Death Rate - Weekly', 'Death Rate - Cumulative',
#        'Population', 'Row ID', 'ZIP Code Location'],
#       dtype='object')

# %%
sns.pairplot(df)

# %%
sns.distplot(df['Population'])

# %%
sns.heatmap(df.corr())

# %%
sns.set_style("darkgrid")
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 8
fig_size[1] = 6
plt.rcParams["figure.figsize"] = fig_size
sns.barplot(x='Week Number', y='Cases - Cumulative', data=df)

# %%
sns.set_style("darkgrid")
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size
sns.barplot(x='ZIP Code', y='Death Rate - Cumulative', data=df)

# %%
# X and y arrays (It should be 2D array)

X = df[['Population']]           # X = np.array (df['Population']) Convert from 1D to 2D
y = df['Deaths - Cumulative']    # X_2d = np.reshape(X, (30, 1))                 

# We separated our data into X and y where X is the features and y is what we're trying to predict.
# X = Training set 
# y= Test set

# %%
#  Train Test Split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
# Creating and Training the Model

from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)

# %%
df.dtypes
# Out:
# ZIP Code                                 object
# Week Number                               int64
# Week Start                               object
# Week End                                 object
# Cases - Weekly                          float64
# Cases - Cumulative                      float64
# Case Rate - Weekly                      float64
# Case Rate - Cumulative                  float64
# Tests - Weekly                          float64
# Tests - Cumulative                        int64
# Test Rate - Weekly                      float64
# Test Rate - Cumulative                  float64
# Percent Tested Positive - Weekly        float64
# Percent Tested Positive - Cumulative    float64
# Deaths - Weekly                           int64
# Deaths - Cumulative                       int64
# Death Rate - Weekly                     float64
# Death Rate - Cumulative                 float64
# Population                                int64
# Row ID                                   object
# ...

# %%
#Model Evaluation

# print the intercept
print(lm.intercept_)
# Out:
# -3.8758125395271605

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df

# Holding all other features fixed, a 1 unit increase in Population is associated with an *increase of 0.000788 *.
# Out:
#             Coefficient
# Population     0.000788

# %%
# Predictions from our Model

predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot((y_test-predictions),bins=50);

# %%
# y= aX + b 
# y = death 
# a = Coefficient = 0.000788
# X = population
# b = intercept = -3.87

# Y = (0.000788 * X) + (-3.87)
